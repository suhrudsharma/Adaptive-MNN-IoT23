# %% [markdown]
# <a href="https://colab.research.google.com/github/suhrudsharma/Adaptive-MNN-IoT23/blob/main/adaptive_modular_nn_final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

folders = ["Benign1", "Benign2", "Scan1", "Scan2", "CnC1", "CnC2"]
base = "/content/IoT23"

for f in folders:
    path = os.path.join(base, f, "bro")
    os.makedirs(path, exist_ok=True)

# %%
# !wget -O /content/IoT23/Benign1/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:00--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-Honeypot-Capture-4-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 61653 (60K)
# Saving to: ‘/content/IoT23/Benign1/bro/conn.log.labeled’
#
# /content/IoT23/Beni 100%[===================>]  60.21K   255KB/s    in 0.2s
#
# 2025-12-10 10:27:01 (255 KB/s) - ‘/content/IoT23/Benign1/bro/conn.log.labeled’ saved [61653/61653]

# %%
# !wget -O /content/IoT23/Benign2/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:01--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-Honeypot-Capture-5-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 182147 (178K)
# Saving to: ‘/content/IoT23/Benign2/bro/conn.log.labeled’
#
# /content/IoT23/Beni 100%[===================>] 177.88K   376KB/s    in 0.5s
#
# 2025-12-10 10:27:02 (376 KB/s) - ‘/content/IoT23/Benign2/bro/conn.log.labeled’ saved [182147/182147]

# %%
# !wget -O /content/IoT23/Scan1/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:03--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-34-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2926718 (2.8M)
# Saving to: ‘/content/IoT23/Scan1/bro/conn.log.labeled’
#
# /content/IoT23/Scan 100%[===================>]   2.79M  3.30MB/s    in 0.8s
#
# 2025-12-10 10:27:04 (3.30 MB/s) - ‘/content/IoT23/Scan1/bro/conn.log.labeled’ saved [2926718/2926718]

# %%
# !wget -O /content/IoT23/Scan2/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:04--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1431000 (1.4M)
# Saving to: ‘/content/IoT23/Scan2/bro/conn.log.labeled’
#
# /content/IoT23/Scan 100%[===================>]   1.36M  1.88MB/s    in 0.7s
#
# 2025-12-10 10:27:05 (1.88 MB/s) - ‘/content/IoT23/Scan2/bro/conn.log.labeled’ saved [1431000/1431000]

# %%
# !wget -O /content/IoT23/CnC1/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:05--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-44-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31179 (30K)
# Saving to: ‘/content/IoT23/CnC1/bro/conn.log.labeled’
#
# /content/IoT23/CnC1 100%[===================>]  30.45K  --.-KB/s    in 0.1s
#
# 2025-12-10 10:27:06 (260 KB/s) - ‘/content/IoT23/CnC1/bro/conn.log.labeled’ saved [31179/31179]

# %%
# !wget -O /content/IoT23/CnC2/bro/conn.log.labeled \
"https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled"
# Out:
# --2025-12-10 10:27:06--  https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-20-1/bro/conn.log.labeled
# Resolving mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)... 147.32.82.194
# Connecting to mcfp.felk.cvut.cz (mcfp.felk.cvut.cz)|147.32.82.194|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 419604 (410K)
# Saving to: ‘/content/IoT23/CnC2/bro/conn.log.labeled’
#
# /content/IoT23/CnC2 100%[===================>] 409.77K   689KB/s    in 0.6s
#
# 2025-12-10 10:27:07 (689 KB/s) - ‘/content/IoT23/CnC2/bro/conn.log.labeled’ saved [419604/419604]

# %%
# !find /content/IoT23 -name "conn.log.labeled"
# Out:
# /content/IoT23/Benign1/bro/conn.log.labeled
# /content/IoT23/Benign2/bro/conn.log.labeled
# /content/IoT23/Scan1/bro/conn.log.labeled
# /content/IoT23/CnC1/bro/conn.log.labeled
# /content/IoT23/CnC2/bro/conn.log.labeled
# /content/IoT23/Scan2/bro/conn.log.labeled

# %%
# CELL 1 — Load and Prepare IoT-23 Zeek Flow Dataset

import pandas as pd
import os
import glob

BASE_DIR = "/content/IoT23"

# 1) Locate all official Zeek-labeled logs
conn_files = glob.glob(os.path.join(BASE_DIR, "**", "bro", "conn.log.labeled"), recursive=True)
print("Found labeled files:")
for f in conn_files:
    print(" -", f)

# 2) Zeek conn.log parser
def load_zeek_conn(path):
    fields = None
    with open(path, "r", errors="ignore") as f:
        for line in f:
            if line.startswith("#fields"):
                fields = line.strip().split()[1:]
                break

    if fields is None:
        fields = [
            "ts","uid","id.orig_h","id.orig_p","id.resp_h","id.resp_p",
            "proto","service","duration","orig_bytes","resp_bytes",
            "orig_pkts","resp_pkts","conn_state","label"
        ]

    return pd.read_csv(path, sep="\t", comment="#", names=fields, header=None, low_memory=False)

# 3) Scenario-level ML label assignment
def assign_label_from_scenario(scenario):
    scen = scenario.lower()
    if "benign" in scen: return 0
    if "scan"   in scen: return 1
    if "cnc"    in scen: return 2
    return 2

# 4) Load + prepare all scenarios
all_data = []

for path in conn_files:
    scenario = path.split("/")[-3]
    print(f"\nLoading scenario: {scenario}")

    df = load_zeek_conn(path)

    keep = [
        "ts","id.orig_h","id.orig_p","id.resp_h","id.resp_p","proto","service",
        "duration","orig_bytes","resp_bytes","orig_pkts","resp_pkts","conn_state","label"
    ]
    df = df[[c for c in keep if c in df.columns]].copy()

    # Convert numeric features
    for col in ["duration","orig_bytes","resp_bytes","orig_pkts","resp_pkts"]:
        df[col] = pd.to_numeric(df[col], errors="coerce")  # fixed warning

    df["scenario"] = scenario
    df["ML_label"] = df["scenario"].apply(assign_label_from_scenario)

    print(f"Rows used: {len(df)}")
    all_data.append(df)

# 5) Merge
final_df = pd.concat(all_data, ignore_index=True)
print("\nFINAL MERGED SHAPE:", final_df.shape)

# 6) Save flows
final_df.to_csv("/content/flows.csv", index=False)
print("Saved flows to /content/flows.csv")

final_df.head()
# Out:
# Found labeled files:
#  - /content/IoT23/Benign1/bro/conn.log.labeled
#  - /content/IoT23/Benign2/bro/conn.log.labeled
#  - /content/IoT23/Scan1/bro/conn.log.labeled
#  - /content/IoT23/CnC1/bro/conn.log.labeled
#  - /content/IoT23/CnC2/bro/conn.log.labeled
#  - /content/IoT23/Scan2/bro/conn.log.labeled
#
# Loading scenario: Benign1
# Rows used: 452
#
# Loading scenario: Benign2
# Rows used: 1374
#
# Loading scenario: Scan1
# Rows used: 23145
#
# Loading scenario: CnC1
# Rows used: 237
#
# Loading scenario: CnC2
# Rows used: 3209
#
# Loading scenario: Scan2
# Rows used: 10403
#
# FINAL MERGED SHAPE: (38820, 16)
# Saved flows to /content/flows.csv
#              ts      id.orig_h  id.orig_p        id.resp_h  id.resp_p proto  \
# 0  1.540469e+09  192.168.1.132      58687     216.239.35.4        123   udp
# 1  1.540469e+09  192.168.1.132       1900  239.255.255.250       1900   udp
# 2  1.540469e+09  192.168.1.132      32893     216.239.35.8        123   udp
# 3  1.540470e+09  192.168.1.132      53395       2.16.60.82        443   tcp
# 4  1.540470e+09  192.168.1.132      52801      192.168.1.1         53   udp
#
#   service    duration  orig_bytes  resp_bytes  orig_pkts  resp_pkts  \
# 0       -    0.114184        48.0        48.0          1          1
# 1       -  160.367579      7536.0         0.0         24          0
# 2       -    0.016986        48.0        48.0          1          1
# 3       -    0.003497         0.0         0.0          5          3
# 4     dns    0.036724        34.0       311.0          1          1
#
#   conn_state label scenario  ML_label
# 0         SF   NaN  Benign1         0
# 1         S0   NaN  Benign1         0
# 2         SF   NaN  Benign1         0
# 3         SF   NaN  Benign1         0
# 4         SF   NaN  Benign1         0

# %%
# CELL 2 — Feature Extraction + Normalization



import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load processed flow dataset
df = pd.read_csv("/content/flows.csv", low_memory=False)

print("Original shape:", df.shape)

# Feature set (same type used in base research paper)
features = ["duration", "orig_bytes", "resp_bytes", "orig_pkts", "resp_pkts"]

# Fill missing numeric values
df[features] = df[features].fillna(0)

# Define X (input features) and y (labels)
X = df[features].values
y = df["ML_label"].values

# Normalize features (important for neural networks)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# 80/20 split with stratification to preserve class ratios
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.20, random_state=42, stratify=y
)

print("Training shape:", X_train.shape)
print("Testing shape:", X_test.shape)

# Optional: show class distribution
import numpy as np
unique, counts = np.unique(y, return_counts=True)
print("\nClass distribution (0=Benign, 1=Scan, 2=CnC):")
for u, c in zip(unique, counts):
    print(f"Class {u}: {c} samples")
# Out:
# Original shape: (38820, 16)
# Training shape: (31056, 5)
# Testing shape: (7764, 5)
#
# Class distribution (0=Benign, 1=Scan, 2=CnC):
# Class 0: 1826 samples
# Class 1: 33548 samples
# Class 2: 3446 samples

# %%
# CELL 3 — XGBoost Model

# !pip install xgboost > /dev/null

from xgboost import XGBClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# Train the model
xgb = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    subsample=0.8,
    colsample_bytree=0.8,
    objective="multi:softmax",
    num_class=3,
    random_state=42
)

xgb.fit(X_train, y_train)

# Predictions
y_pred = xgb.predict(X_test)

# Evaluation
print("\nAccuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Benign","Scan","CnC"],
            yticklabels=["Benign","Scan","CnC"])
plt.title("XGBoost Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()
# Out:
# Accuracy: 0.9422977846470891
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.83      0.89       365
#            1       0.96      0.98      0.97      6710
#            2       0.76      0.64      0.70       689
#
#     accuracy                           0.94      7764
#    macro avg       0.89      0.82      0.85      7764
# weighted avg       0.94      0.94      0.94      7764

# %%
# CELL 4 — 1D-CNN Deep Learning Model


import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import numpy as np

# CNN expects 3D input: (samples, timesteps, features)
# Our features = 5, so we reshape from (N,5) → (N,5,1)
X_train_cnn = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test_cnn  = X_test.reshape((X_test.shape[0],  X_test.shape[1],  1))

# CNN Model
model = Sequential([
    Conv1D(32, kernel_size=2, activation='relu', input_shape=(5,1)),
    Conv1D(64, kernel_size=2, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(3, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train
history = model.fit(
    X_train_cnn, y_train,
    epochs=10,
    batch_size=64,
    validation_split=0.2,
    verbose=1
)

# Predict
y_pred_cnn = np.argmax(model.predict(X_test_cnn), axis=1)

# Evaluation
print("\nCNN Test Accuracy:", accuracy_score(y_test, y_pred_cnn))
print("\nClassification Report:")
print(classification_report(y_test, y_pred_cnn))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_cnn)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Greens",
            xticklabels=["Benign","Scan","CnC"],
            yticklabels=["Benign","Scan","CnC"])
plt.title("CNN Confusion Matrix")
plt.xlabel("Predicted"); plt.ylabel("Actual")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.8497 - loss: 0.6756 - val_accuracy: 0.8620 - val_loss: 0.4901
# Epoch 2/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8655 - loss: 0.4920 - val_accuracy: 0.8620 - val_loss: 0.4885
# Epoch 3/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8672 - loss: 0.4864 - val_accuracy: 0.8620 - val_loss: 0.4918
# Epoch 4/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8670 - loss: 0.4885 - val_accuracy: 0.8620 - val_loss: 0.4846
# Epoch 5/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8636 - loss: 0.4857 - val_accuracy: 0.8624 - val_loss: 0.4830
# Epoch 6/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8672 - loss: 0.4803 - val_accuracy: 0.8635 - val_loss: 0.4793
# Epoch 7/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8670 - loss: 0.4781 - val_accuracy: 0.8640 - val_loss: 0.4787
# Epoch 8/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8689 - loss: 0.4787 - val_accuracy: 0.8680 - val_loss: 0.4760
# Epoch 9/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8700 - loss: 0.4732 - val_accuracy: 0.8680 - val_loss: 0.4747
# Epoch 10/10
# 389/389 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8680 - loss: 0.4803 - val_accuracy: 0.8680 - val_loss: 0.4749
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 952us/step
#
# CNN Test Accuracy: 0.8713292117465224
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.16      0.27       365
#            1       0.87      1.00      0.93      6710
#            2       0.00      0.00      0.00       689
#
#     accuracy                           0.87      7764
#    macro avg       0.60      0.39      0.40      7764
# weighted avg       0.80      0.87      0.82      7764
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# CELL 5 — Three binary modules (XGBoost + small DNN)
# Modules: Benign-vs-others, Scan-vs-others, CnC-vs-others

# Requirements: X_train, X_test, y_train, y_test, scaler must exist from previous cells

# 1) Imports
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# Utility to plot confusion matrix
def plot_cm(cm, title):
    plt.figure(figsize=(4,3))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
    plt.title(title)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.show()

# Map multi-class labels to binary for a target class
def make_binary_labels(y, target_class):
    # returns array: 1 for target_class, 0 otherwise
    return np.where(y == target_class, 1, 0)

# Keep track of trained models and outputs
modules = ["Benign", "Scan", "CnC"]
target_map = {"Benign":0, "Scan":1, "CnC":2}

xgb_modules = {}
dnn_modules = {}
probs_train = {}  # store module probabilities on train (for combiner later if needed)
probs_test = {}   # store module probabilities on test

# Use a small DNN builder function
def build_small_dnn(input_shape):
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(64, activation='relu'),
        Dropout(0.2),
        Dense(32, activation='relu'),
        Dropout(0.1),
        Dense(1, activation='sigmoid')  # binary output
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Training loop for each module
for mod in modules:
    print(f"\n\n===== Module: {mod} (binary) =====")
    tclass = target_map[mod]

    # Prepare binary labels
    y_train_bin = make_binary_labels(y_train, tclass)
    y_test_bin  = make_binary_labels(y_test, tclass)

    # --- XGBoost (fast, strong baseline) ---
    print("\n-> Training XGBoost...")
    xgb = XGBClassifier(
        n_estimators=150,
        max_depth=5,
        learning_rate=0.1,
        use_label_encoder=False,
        eval_metric='logloss',
        random_state=42
    )
    xgb.fit(X_train, y_train_bin)
    y_pred_xgb = xgb.predict(X_test)
    y_prob_xgb = xgb.predict_proba(X_test)[:,1]

    print("XGBoost metrics:")
    print(" Accuracy:", accuracy_score(y_test_bin, y_pred_xgb))
    print(classification_report(y_test_bin, y_pred_xgb, digits=4))
    cm_x = confusion_matrix(y_test_bin, y_pred_xgb)
    plot_cm(cm_x, f"XGB CM - {mod}")

    # Save
    xgb_modules[mod] = xgb
    probs_test[f"xgb_{mod}"] = y_prob_xgb

    # --- Small DNN (Keras) ---
    print("\n-> Training small DNN...")
    dnn = build_small_dnn(X_train.shape[1])
    # Early stopping to avoid long runs
    es = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True, verbose=0)
    dnn.fit(X_train, y_train_bin, epochs=30, batch_size=128, validation_split=0.15, callbacks=[es], verbose=0)

    y_prob_dnn = dnn.predict(X_test).flatten()
    y_pred_dnn = (y_prob_dnn >= 0.5).astype(int)

    print("DNN metrics:")
    print(" Accuracy:", accuracy_score(y_test_bin, y_pred_dnn))
    print(classification_report(y_test_bin, y_pred_dnn, digits=4))
    cm_d = confusion_matrix(y_test_bin, y_pred_dnn)
    plot_cm(cm_d, f"DNN CM - {mod}")

    # Save
    dnn_modules[mod] = dnn
    probs_test[f"dnn_{mod}"] = y_prob_dnn

# Summarize stored probability keys
print("\nStored module probability keys (test):", list(probs_test.keys()))
# Out:
# ===== Module: Benign (binary) =====
#
# -> Training XGBoost...
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:27:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost metrics:
#  Accuracy: 0.9893096342091705
#               precision    recall  f1-score   support
#
#            0     0.9902    0.9986    0.9944      7399
#            1     0.9669    0.8000    0.8756       365
#
#     accuracy                         0.9893      7764
#    macro avg     0.9786    0.8993    0.9350      7764
# weighted avg     0.9891    0.9893    0.9888      7764
# -> Training small DNN...
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 811us/step
# DNN metrics:
#  Accuracy: 0.9598145285935085
#               precision    recall  f1-score   support
#
#            0     0.9601    0.9993    0.9793      7399
#            1     0.9206    0.1589    0.2710       365
#
#     accuracy                         0.9598      7764
#    macro avg     0.9404    0.5791    0.6252      7764
# weighted avg     0.9583    0.9598    0.9460      7764
# ===== Module: Scan (binary) =====
#
# -> Training XGBoost...
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:28:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost metrics:
#  Accuracy: 0.9444873776403916
#               precision    recall  f1-score   support
#
#            0     0.8480    0.7201    0.7789      1054
#            1     0.9571    0.9797    0.9683      6710
#
#     accuracy                         0.9445      7764
#    macro avg     0.9025    0.8499    0.8736      7764
# weighted avg     0.9423    0.9445    0.9425      7764
# -> Training small DNN...
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# DNN metrics:
#  Accuracy: 0.8721020092735703
#               precision    recall  f1-score   support
#
#            0     0.9692    0.0598    0.1126      1054
#            1     0.8713    0.9997    0.9311      6710
#
#     accuracy                         0.8721      7764
#    macro avg     0.9203    0.5297    0.5218      7764
# weighted avg     0.8846    0.8721    0.8200      7764
# ===== Module: CnC (binary) =====
#
# -> Training XGBoost...
# /usr/local/lib/python3.12/dist-packages/xgboost/training.py:199: UserWarning: [10:28:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost metrics:
#  Accuracy: 0.9502833590932509
#               precision    recall  f1-score   support
#
#            0     0.9650    0.9811    0.9729      7075
#            1     0.7653    0.6343    0.6937       689
#
#     accuracy                         0.9503      7764
#    macro avg     0.8651    0.8077    0.8333      7764
# weighted avg     0.9472    0.9503    0.9482      7764
# -> Training small DNN...
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 968us/step
# DNN metrics:
#  Accuracy: 0.9113858835651726
#               precision    recall  f1-score   support
#
#            0     0.9114    1.0000    0.9536      7075
#            1     1.0000    0.0015    0.0029       689
#
#     accuracy                         0.9114      7764
#    macro avg     0.9557    0.5007    0.4783      7764
# weighted avg     0.9192    0.9114    0.8693      7764
# Stored module probability keys (test): ['xgb_Benign', 'dnn_Benign', 'xgb_Scan', 'dnn_Scan', 'xgb_CnC', 'dnn_CnC']

# %%
# CELL 6 — Adaptive Modular Neural Network (AMNN) combiner (hybrid stacking)
# Uses module probabilities from XGBoost + DNN modules (from CELL 5)

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1) Build module probability features for a dataset selector (train/val/test)
def build_module_probs(X, xgb_models, dnn_models):
    """
    X: (N, F) scaled numeric features
    returns: (N, 6) array of probabilities:
    [xgb_benign, xgb_scan, xgb_cnc, dnn_benign, dnn_scan, dnn_cnc]
    """
    probs = []
    # XGBoost module probs: predict_proba -> we used binary tasks, so idx 1 = prob of positive (target)
    p_xgb_b = xgb_models["Benign"].predict_proba(X)[:,1]
    p_xgb_s = xgb_models["Scan"].predict_proba(X)[:,1]
    p_xgb_c = xgb_models["CnC"].predict_proba(X)[:,1]
    # DNN models: they output a single probability per sample
    p_dnn_b = dnn_models["Benign"].predict(X).flatten()
    p_dnn_s = dnn_models["Scan"].predict(X).flatten()
    p_dnn_c = dnn_models["CnC"].predict(X).flatten()
    probs = np.vstack([p_xgb_b, p_xgb_s, p_xgb_c, p_dnn_b, p_dnn_s, p_dnn_c]).T
    return probs

# Build meta-features for TRAIN and TEST
meta_X_train_full = build_module_probs(X_train, xgb_modules, dnn_modules)
meta_X_test = build_module_probs(X_test, xgb_modules, dnn_modules)
meta_y_train_full = y_train  # same labels

print("Meta-features shapes:", meta_X_train_full.shape, meta_X_test.shape)

# 2) Split meta training into train_meta and val_meta to tune/log performance
from sklearn.model_selection import train_test_split
meta_X_train, meta_X_val, meta_y_train, meta_y_val = train_test_split(
    meta_X_train_full, meta_y_train_full, test_size=0.20, random_state=42, stratify=meta_y_train_full
)
print("Meta train/val shapes:", meta_X_train.shape, meta_X_val.shape)

# 3) Baseline 1: simple argmax of XGBoost module probs -> predicted class by argmax of [p_b, p_s, p_c]
def argmax_from_xgb(X_meta):
    p_xgb_only = X_meta[:,0:3]  # first 3 are xgb probs
    preds = np.argmax(p_xgb_only, axis=1)  # 0->Benign,1->Scan,2->CnC
    return preds

# Baseline 2: argmax of DNN module probs
def argmax_from_dnn(X_meta):
    p_dnn_only = X_meta[:,3:6]
    preds = np.argmax(p_dnn_only, axis=1)
    return preds

# Evaluate baselines on test set
pred_xgb_baseline = argmax_from_xgb(meta_X_test)
pred_dnn_baseline = argmax_from_dnn(meta_X_test)

print("\nBaseline XGB-modules performance on test:")
print("Accuracy:", accuracy_score(y_test, pred_xgb_baseline))
print(classification_report(y_test, pred_xgb_baseline, digits=4))

print("\nBaseline DNN-modules performance on test:")
print("Accuracy:", accuracy_score(y_test, pred_dnn_baseline))
print(classification_report(y_test, pred_dnn_baseline, digits=4))

# 4) Train meta-classifier (Logistic Regression multinomial)
meta_clf = LogisticRegression(multi_class='multinomial', solver='lbfgs', max_iter=2000, random_state=42)
meta_clf.fit(meta_X_train, meta_y_train)

# Evaluate on validation set
val_pred = meta_clf.predict(meta_X_val)
print("\nMeta-classifier (val) Accuracy:", accuracy_score(meta_y_val, val_pred))
print(classification_report(meta_y_val, val_pred, digits=4))

# Evaluate final on test set
meta_test_pred = meta_clf.predict(meta_X_test)
print("\nAMNN (meta) on test Accuracy:", accuracy_score(y_test, meta_test_pred))
print(classification_report(y_test, meta_test_pred, digits=4))

# Confusion matrix for meta-combiner
cm_meta = confusion_matrix(y_test, meta_test_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm_meta, annot=True, fmt='d', cmap='Oranges',
            xticklabels=["Benign","Scan","CnC"], yticklabels=["Benign","Scan","CnC"])
plt.title("AMNN (meta) Confusion Matrix")
plt.xlabel("Predicted"); plt.ylabel("Actual")
plt.show()

# 5) Save meta model (optional) and show feature importance (coeffs)
import joblib
joblib.dump(meta_clf, "/content/amnn_meta_clf.joblib")
print("Saved meta-classifier to /content/amnn_meta_clf.joblib")

# Show weights learned (logistic regression coefficients)
coef = meta_clf.coef_  # shape (3,6)
print("\nMeta-classifier coefficients (rows = class 0/1/2, cols = xgb_b,xgb_s,xgb_c,dnn_b,dnn_s,dnn_c):")
print(coef)

# 6) Quick comparison table
from sklearn.metrics import f1_score, precision_score, recall_score
def summarize(name, y_true, y_pred):
    return {
        "name": name,
        "accuracy": accuracy_score(y_true, y_pred),
        "f1_macro": f1_score(y_true, y_pred, average='macro'),
        "precision_macro": precision_score(y_true, y_pred, average='macro'),
        "recall_macro": recall_score(y_true, y_pred, average='macro')
    }

summary = [
    summarize("XGB-module-argmax", y_test, pred_xgb_baseline),
    summarize("DNN-module-argmax", y_test, pred_dnn_baseline),
    summarize("AMNN-meta", y_test, meta_test_pred)
]

import pandas as pd
print("\nSummary comparison:")
pd.DataFrame(summary)
# Out:
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 1s 683us/step
# 971/971 ━━━━━━━━━━━━━━━━━━━━ 1s 680us/step
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step
# 243/243 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# Meta-features shapes: (31056, 6) (7764, 6)
# Meta train/val shapes: (24844, 6) (6212, 6)
#
# Baseline XGB-modules performance on test:
# Accuracy: 0.9422977846470891
#               precision    recall  f1-score   support
#
#            0     0.9579    0.8110    0.8783       365
#            1     0.9571    0.9802    0.9685      6710
#            2     0.7599    0.6430    0.6965       689
#
#     accuracy                         0.9423      7764
#    macro avg     0.8916    0.8114    0.8478      7764
# weighted avg     0.9396    0.9423    0.9401      7764
#
#
# Baseline DNN-modules performance on test:
# Accuracy: 0.871586810922205
#               precision    recall  f1-score   support
#
#            0     0.9206    0.1589    0.2710       365
#            1     0.8712    0.9997    0.9310      6710
#            2     1.0000    0.0015    0.0029       689
#
#     accuracy                         0.8716      7764
#    macro avg     0.9306    0.3867    0.4016      7764
# weighted avg     0.8849    0.8716    0.8176      7764
#
#
# Meta-classifier (val) Accuracy: 0.943979394719897
#               precision    recall  f1-score   support
#
#            0     0.9400    0.8048    0.8672       292
#            1     0.9567    0.9829    0.9696      5368
#            2     0.7897    0.6395    0.7067       552
#
#     accuracy                         0.9440      6212
#    macro avg     0.8955    0.8090    0.8478      6212
# weighted avg     0.9410    0.9440    0.9414      6212
#
#
# AMNN (meta) on test Accuracy: 0.9422977846470891
#               precision    recall  f1-score   support
#
#            0     0.9581    0.8137    0.8800       365
#            1     0.9571    0.9802    0.9685      6710
#            2     0.7595    0.6415    0.6955       689
#
#     accuracy                         0.9423      7764
#    macro avg     0.8915    0.8118    0.8480      7764
# weighted avg     0.9396    0.9423    0.9401      7764
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:1247: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.7. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# Saved meta-classifier to /content/amnn_meta_clf.joblib
#
# Meta-classifier coefficients (rows = class 0/1/2, cols = xgb_b,xgb_s,xgb_c,dnn_b,dnn_s,dnn_c):
# [[ 4.98248086 -2.16791831 -2.57052306  0.26549662  0.05170932 -0.22060331]
#  [-4.10993486  3.566761    0.0703555   0.19221119 -0.36687302 -0.09686643]
#  [-0.872546   -1.39884269  2.50016756 -0.45770781  0.31516371  0.31746974]]
#
# Summary comparison:
#                 name  accuracy  f1_macro  precision_macro  recall_macro
# 0  XGB-module-argmax  0.942298  0.847789         0.891621      0.811366
# 1  DNN-module-argmax  0.871587  0.401649         0.930601      0.386686
# 2          AMNN-meta  0.942298  0.848001         0.891529      0.811796

# %%
# CELL 7 — Save all models

import os
import joblib
import tensorflow as tf

BASE_SAVE = "/content/saved_models"
os.makedirs(BASE_SAVE, exist_ok=True)

# 1) SAVE SCALER
os.makedirs(f"{BASE_SAVE}/scaler", exist_ok=True)
joblib.dump(scaler, f"{BASE_SAVE}/scaler/standard_scaler.pkl")
print("Saved scaler.")

# 2) SAVE XGBOOST MODULES
os.makedirs(f"{BASE_SAVE}/xgb_modules", exist_ok=True)
for mod in xgb_modules:
    joblib.dump(xgb_modules[mod], f"{BASE_SAVE}/xgb_modules/xgb_{mod}.pkl")
    print(f"Saved XGB module: {mod}")

# 3) SAVE DNN MODULES
os.makedirs(f"{BASE_SAVE}/dnn_modules", exist_ok=True)
for mod in dnn_modules:
    dnn_modules[mod].save(f"{BASE_SAVE}/dnn_modules/dnn_{mod}.h5")
    print(f"Saved DNN module: {mod}")

# 4) SAVE AMNN META-CLASSIFIER
os.makedirs(f"{BASE_SAVE}/amnn", exist_ok=True)
joblib.dump(meta_clf, f"{BASE_SAVE}/amnn/meta_classifier.pkl")
print("Saved AMNN meta-classifier.")

print("\nAll models saved successfully!")
print("Saved in folder:", BASE_SAVE)

# Optional: list files saved
# !find /content/saved_models -type f
# Out:
# Saved scaler.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Saved XGB module: Benign
# Saved XGB module: Scan
# Saved XGB module: CnC
# Saved DNN module: Benign
# Saved DNN module: Scan
# Saved DNN module: CnC
# Saved AMNN meta-classifier.
#
# All models saved successfully!
# Saved in folder: /content/saved_models
# /content/saved_models/dnn_modules/dnn_Benign.h5
# /content/saved_models/dnn_modules/dnn_Scan.h5
# /content/saved_models/dnn_modules/dnn_CnC.h5
# /content/saved_models/amnn/meta_classifier.pkl
# /content/saved_models/scaler/standard_scaler.pkl
# /content/saved_models/xgb_modules/xgb_CnC.pkl
# /content/saved_models/xgb_modules/xgb_Scan.pkl
# /content/saved_models/xgb_modules/xgb_Benign.pkl

# %%
# CELL 8 — Unified AMNN Inference Pipeline


import joblib
import numpy as np
import tensorflow as tf

# Paths to saved models
BASE = "/content/saved_models"

# Load scaler
scaler_loaded = joblib.load(f"{BASE}/scaler/standard_scaler.pkl")

# Load XGB modules
xgb_benign = joblib.load(f"{BASE}/xgb_modules/xgb_Benign.pkl")
xgb_scan   = joblib.load(f"{BASE}/xgb_modules/xgb_Scan.pkl")
xgb_cnc    = joblib.load(f"{BASE}/xgb_modules/xgb_CnC.pkl")

# Load DNN modules
dnn_benign = tf.keras.models.load_model(f"{BASE}/dnn_modules/dnn_Benign.h5")
dnn_scan   = tf.keras.models.load_model(f"{BASE}/dnn_modules/dnn_Scan.h5")
dnn_cnc    = tf.keras.models.load_model(f"{BASE}/dnn_modules/dnn_CnC.h5")

# Load meta-classifier
meta_clf_loaded = joblib.load(f"{BASE}/amnn/meta_classifier.pkl")

print("All models loaded successfully!")


# ----------------------------------------------------
# FINAL AMNN PREDICTION FUNCTION
# ----------------------------------------------------
def amnn_predict(flow_dict):
    """
    flow_dict must contain the 5 numerical features:
      duration, orig_bytes, resp_bytes, orig_pkts, resp_pkts
    Example:
      {"duration": 1.2, "orig_bytes": 50, "resp_bytes": 300,
       "orig_pkts": 10, "resp_pkts": 12}
    Returns:
      final_class (0=Benign, 1=Scan, 2=CnC)
    """

    # 1) Convert dict → numpy array
    features = np.array([
        flow_dict["duration"],
        flow_dict["orig_bytes"],
        flow_dict["resp_bytes"],
        flow_dict["orig_pkts"],
        flow_dict["resp_pkts"]
    ]).reshape(1, -1)

    # 2) Scale
    X_scaled = scaler_loaded.transform(features)

    # 3) Get probabilities from XGB modules
    p_xgb_b = xgb_benign.predict_proba(X_scaled)[:,1]
    p_xgb_s = xgb_scan.predict_proba(X_scaled)[:,1]
    p_xgb_c = xgb_cnc.predict_proba(X_scaled)[:,1]

    # 4) Get probabilities from DNN modules
    p_dnn_b = dnn_benign.predict(X_scaled).flatten()
    p_dnn_s = dnn_scan.predict(X_scaled).flatten()
    p_dnn_c = dnn_cnc.predict(X_scaled).flatten()

    # 5) Build meta-feature vector
    meta_vec = np.array([
        p_xgb_b[0], p_xgb_s[0], p_xgb_c[0],
        p_dnn_b[0], p_dnn_s[0], p_dnn_c[0]
    ]).reshape(1, -1)

    # 6) Meta-classifier final prediction
    final_class = meta_clf_loaded.predict(meta_vec)[0]

    return final_class



# TEST THE FINAL PIPELINE WITH A SAMPLE INPUT

sample_flow = {
    "duration": 1.5,
    "orig_bytes": 100,
    "resp_bytes": 200,
    "orig_pkts": 5,
    "resp_pkts": 7
}

print("Sample Prediction:", amnn_predict(sample_flow))
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# All models loaded successfully!
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Sample Prediction: 2

# %%
# !zip -r saved_models.zip /content/saved_models
# Out:
#   adding: content/saved_models/ (stored 0%)
#   adding: content/saved_models/dnn_modules/ (stored 0%)
#   adding: content/saved_models/dnn_modules/dnn_Benign.h5 (deflated 51%)
#   adding: content/saved_models/dnn_modules/dnn_Scan.h5 (deflated 51%)
#   adding: content/saved_models/dnn_modules/dnn_CnC.h5 (deflated 51%)
#   adding: content/saved_models/amnn/ (stored 0%)
#   adding: content/saved_models/amnn/meta_classifier.pkl (deflated 29%)
#   adding: content/saved_models/scaler/ (stored 0%)
#   adding: content/saved_models/scaler/standard_scaler.pkl (deflated 23%)
#   adding: content/saved_models/xgb_modules/ (stored 0%)
#   adding: content/saved_models/xgb_modules/xgb_CnC.pkl (deflated 77%)
#   adding: content/saved_models/xgb_modules/xgb_Scan.pkl (deflated 75%)
#   adding: content/saved_models/xgb_modules/xgb_Benign.pkl (deflated 76%)

# %%
# Colab-ready cell: MNN implementation for IoT-23
# Paste and run. Requires: pip install imbalanced-learn xgboost (optional)
# !pip install -q imbalanced-learn xgboost

import os
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks, losses, optimizers
from imblearn.over_sampling import SMOTE
import joblib
import matplotlib.pyplot as plt
import seaborn as sns

# ---------- CONFIG ----------
DATA_PATH = "/content/conn.log.labeled"   # change to your IoT-23 CSV path
RANDOM_SEEDS = [42, 2024, 7]               # ensemble over seeds
RESULTS_DIR = "/content/mnn_results"
os.makedirs(RESULTS_DIR, exist_ok=True)

# Module classes (labels in IoT-23 that you have to map to these three categories)
# Adjust label mapping as needed depending on your conn.log.labeled label names
BENIGN_LABELS = ["Benign"]               # or "benign" depending on your file
SCAN_LABELS = ["Scan"]                   # adjust
CNC_LABELS = ["C&C", "CnC", "Malicious"] # adjust

# ---------- UTILITIES ----------
def set_global_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

def read_iot23(path):
    """Read IoT-23 preprocessed CSV. If your conn.log.labeled has a different layout,
       adapt this function to extract the same features used in the paper.
    """
    df = pd.read_csv(path)
    # Expect a column 'label' with class names - adjust if different
    if 'label' not in df.columns and 'Label' in df.columns:
        df.rename(columns={'Label': 'label'}, inplace=True)
    return df

def prepare_features(df, feature_cols=None, scaler=None, fit_scaler=True):
    if feature_cols is None:
        # Heuristic: drop non-numeric cols, drop label
        feature_cols = [c for c in df.columns if df[c].dtype in [np.float64, np.int64]]
        # If 'label' is numeric, remove it
        feature_cols = [c for c in feature_cols if c.lower() not in ('label','labels','class')]
    X = df[feature_cols].astype(float).fillna(0.0).values
    if scaler is None:
        scaler = StandardScaler()
    if fit_scaler:
        X = scaler.fit_transform(X)
    else:
        X = scaler.transform(X)
    return X, scaler, feature_cols

def map_to_three_labels(y_raw):
    """Map dataset labels to 'Benign', 'Scan', 'CnC' strings.
       Modify mapping rules according to your file's label names.
    """
    y3 = []
    for v in y_raw:
        s = str(v).lower()
        if 'benign' in s:
            y3.append('Benign')
        elif 'scan' in s or 'scanning' in s:
            y3.append('Scan')
        else:
            # remaining and explicit 'cnc' or 'c&c' etc
            y3.append('C&C')
    return np.array(y3)

# ---------- MODEL: small binary DNN for a module ----------
def build_module_model(input_dim, hidden_sizes=[128,64], dropout=0.2):
    inp = layers.Input(shape=(input_dim,))
    x = inp
    for h in hidden_sizes:
        x = layers.Dense(h, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(dropout)(x)
    out = layers.Dense(1, activation='sigmoid')(x)
    model = models.Model(inputs=inp, outputs=out)
    model.compile(optimizer=optimizers.Adam(learning_rate=1e-3),
                  loss=losses.BinaryCrossentropy(),
                  metrics=['AUC'])
    return model

# Optional focal loss for severe class imbalance:
def focal_loss(gamma=2., alpha=.25):
    def fl(y_true, y_pred):
        y_pred = tf.clip_by_value(y_pred, 1e-7, 1-1e-7)
        pt = tf.where(tf.equal(y_true,1), y_pred, 1-y_pred)
        w = tf.where(tf.equal(y_true,1), alpha, (1-alpha))
        return -w * tf.math.pow(1-pt, gamma) * tf.math.log(pt)
    return fl

# ---------- TRAIN & EVAL ----------
def train_binary_module(X_train, y_train, X_val, y_val, seed=42, use_focal=False, smote=False):
    set_global_seed(seed)
    if smote:
        sm = SMOTE(random_state=seed)
        X_train, y_train = sm.fit_resample(X_train, y_train)
    model = build_module_model(X_train.shape[1])
    if use_focal:
        model.compile(optimizer=optimizers.Adam(1e-3), loss=focal_loss(), metrics=['AUC'])
    es = callbacks.EarlyStopping(monitor='val_loss', patience=6, restore_best_weights=True)
    hist = model.fit(X_train, y_train, validation_data=(X_val, y_val),
                     epochs=100, batch_size=1024, callbacks=[es], verbose=0)
    return model, hist

def module_predict_proba(model, X):
    return model.predict(X, batch_size=4096).ravel()

# ---------- END-TO-END RUN for one seed ----------
def run_mnn_for_seed(df, seed=42, use_smote_on_cnc=False, use_focal=False):
    set_global_seed(seed)
    # Map to 3-class labels
    df2 = df.copy()
    df2['label3'] = map_to_three_labels(df2['label'].values)
    # Train/val/test split (stratified)
    X_full, scaler, feat_cols = prepare_features(df2)
    le = LabelEncoder()
    y3 = le.fit_transform(df2['label3'].values)  # 0:Benign,1:CnC,2:Scan possibly order differs - check mapping
    # Use stratified split
    X_train, X_temp, y_train, y_temp, lbl_train, lbl_temp = train_test_split(X_full, y3, df2['label3'].values,
                                                                             test_size=0.4, random_state=seed,
                                                                             stratify=y3)
    X_val, X_test, y_val, y_test, lbl_val, lbl_test = train_test_split(X_temp, y_temp, lbl_temp,
                                                                       test_size=0.5, random_state=seed,
                                                                       stratify=y_temp)
    # Save scaler & feature columns for reproducibility
    joblib.dump(scaler, os.path.join(RESULTS_DIR, f"scaler_seed{seed}.pkl"))
    pd.DataFrame({'feature': feat_cols}).to_csv(os.path.join(RESULTS_DIR, f"features_seed{seed}.csv"), index=False)

    # Build binary labels for modules: module outputs prob(class)
    # We'll create three modules: Benign, Scan, C&C each "is class vs rest"
    label_names = ['Benign','Scan','C&C']
    module_models = {}
    module_val_preds = {}
    module_test_preds = {}
    for cls in label_names:
        y_train_bin = (lbl_train == cls).astype(int)
        y_val_bin   = (lbl_val   == cls).astype(int)
        y_test_bin  = (lbl_test  == cls).astype(int)
        smote = (use_smote_on_cnc and cls in ('C&C',))
        model, hist = train_binary_module(X_train, y_train_bin, X_val, y_val_bin,
                                          seed=seed, use_focal=use_focal, smote=smote)
        module_models[cls] = model
        module_val_preds[cls] = module_predict_proba(model, X_val)
        module_test_preds[cls] = module_predict_proba(model, X_test)
        # save model
        model.save(os.path.join(RESULTS_DIR, f"module_{cls}_seed{seed}.keras"))

    # Final decision rule: take argmax over module probabilities for each sample
    proba_matrix_test = np.vstack([module_test_preds[c] for c in label_names]).T
    pred_idx = np.argmax(proba_matrix_test, axis=1)
    pred_labels = [label_names[i] for i in pred_idx]

    # Evaluate
    acc = accuracy_score(lbl_test, pred_labels)
    rep = classification_report(lbl_test, pred_labels, output_dict=False)
    cm = confusion_matrix(lbl_test, pred_labels, labels=label_names)

    # Save outputs
    np.save(os.path.join(RESULTS_DIR, f"proba_test_seed{seed}.npy"), proba_matrix_test)
    pd.DataFrame(cm, index=label_names, columns=label_names).to_csv(os.path.join(RESULTS_DIR, f"cm_seed{seed}.csv"))
    with open(os.path.join(RESULTS_DIR, f"report_seed{seed}.txt"), 'w') as f:
        f.write(f"Accuracy: {acc}\n\n")
        f.write(rep)

    return dict(seed=seed, acc=acc, report=rep, cm=cm, labels=label_names)

# ---------- MASTER RUN over seeds (ensemble averaging) ----------
def master_run(data_path=DATA_PATH, seeds=RANDOM_SEEDS, use_smote_on_cnc=False, use_focal=False):
    df = read_iot23(data_path)
    results = []
    for s in seeds:
        print("Running seed:", s)
        res = run_mnn_for_seed(df, seed=s, use_smote_on_cnc=use_smote_on_cnc, use_focal=use_focal)
        print("Seed", s, "acc:", res['acc'])
        results.append(res)
    # Aggregate
    accs = [r['acc'] for r in results]
    print("Acc per seed:", accs)
    print("Mean acc: %.4f, std: %.4f" % (np.mean(accs), np.std(accs)))
    # Optionally produce combined confusion matrix by summing per-seed confusion matrices (or majority voting)
    cms = [r['cm'] for r in results]
    cm_sum = np.sum(cms, axis=0)
    labels = results[0]['labels']
    pd.DataFrame(cm_sum, index=labels, columns=labels).to_csv(os.path.join(RESULTS_DIR, "cm_aggregate.csv"))
    # Plot aggregate confusion matrix
    plt.figure(figsize=(6,5))
    sns.heatmap(cm_sum, annot=True, fmt='d', xticklabels=labels, yticklabels=labels)
    plt.title("Aggregate confusion matrix (sum over seeds)")
    plt.ylabel("True")
    plt.xlabel("Pred")
    plt.savefig(os.path.join(RESULTS_DIR, "cm_aggregate.png"))
    plt.show()
    return results

# ---------- RUN ----------
# Make sure your conn.log.labeled has a 'label' column. If not, adjust read/write.
results = master_run(DATA_PATH, seeds=RANDOM_SEEDS, use_smote_on_cnc=True, use_focal=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-930865075.py in <cell line: 0>()
#     206 # ---------- RUN ----------
#     207 # Make sure your conn.log.labeled has a 'label' column. If not, adjust read/write.
# --> 208 results = master_run(DATA_PATH, seeds=RANDOM_SEEDS, use_smote_on_cnc=True, use_focal=False)
#
# /tmp/ipython-input-930865075.py in master_run(data_path, seeds, use_smote_on_cnc, use_focal)
#     178 # ---------- MASTER RUN over seeds (ensemble averaging) ----------
#     179 def master_run(data_path=DATA_PATH, seeds=RANDOM_SEEDS, use_smote_on_cnc=False, use_focal=False):
# --> 180     df = read_iot23(data_path)
#     181     results = []
#     182     for s in seeds:
#
# /tmp/ipython-input-930865075.py in read_iot23(path)
#      39        adapt this function to extract the same features used in the paper.
#      40     """
# ---> 41     df = pd.read_csv(path)
#      42     # Expect a column 'label' with class names - adjust if different
#      43     if 'label' not in df.columns and 'Label' in df.columns:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/conn.log.labeled'

# %%
# !ls /content
# Out:
# amnn_meta_clf.joblib  IoT23	   sample_data	 saved_models.zip
# flows.csv	      mnn_results  saved_models

# %%
# Re-merge the original conn.log.labeled files robustly and create iot23_final.csv
import glob
import pandas as pd
import numpy as np

base = "/content/IoT23"
paths = glob.glob(f"{base}/**/conn.log.labeled", recursive=True)
print("Found files:")
for p in paths:
    print(" ", p)

# Read each file directly (skip comment lines starting with '#')
dfs = []
for p in paths:
    print("Reading", p)
    dfp = pd.read_csv(p, sep=r"\s+", engine="python", comment="#", header=None)
    dfs.append(dfp)

full_df = pd.concat(dfs, ignore_index=True)
print("Concatenated shape:", full_df.shape)

# We expect 23 columns (you had 23). If not, abort and report.
ncols = full_df.shape[1]
print("Number of columns detected:", ncols)
if ncols < 20:
    raise ValueError("Unexpected number of columns in merged data. Post here the shape.")

# Assign a 23-column name list — if ncols != 23, create generic names of correct length
if ncols == 23:
    columns = [
        "ts", "uid", "id_orig_h", "id_orig_p", "id_resp_h", "id_resp_p",
        "proto", "service", "duration", "orig_bytes", "resp_bytes",
        "conn_state", "local_orig", "local_resp", "missed_bytes",
        "history", "orig_pkts", "orig_ip_bytes", "resp_pkts",
        "resp_ip_bytes", "tunnel_parents", "label", "label_source"
    ]
else:
    # fallback: generate generic col names and we will inspect later
    columns = [f"c{i}" for i in range(ncols)]
    print("Using fallback generic column names.")

full_df.columns = columns

# Quick sanity checks and fix-ups
# Some fields use '-' for missing. Replace '-' with NaN for clarity in label column.
full_df["label"] = full_df["label"].astype(str).replace({"-": np.nan})

print("\nPreview (first 6 rows):")
display(full_df.head(6))

print("\nColumn counts (non-null):")
print(full_df.count())

print("\nUnique label values (raw):")
print(full_df["label"].value_counts(dropna=False))

# Map raw label values to three classes safely
def map_label_safe(v):
    if pd.isna(v):
        return "Unknown"
    s = str(v).lower()
    if "benign" in s:
        return "Benign"
    if "scan" in s:
        return "Scan"
    # some IoT-23 use 'malicious' or family names -> treat as C&C
    return "C&C"

full_df["label3"] = full_df["label"].apply(map_label_safe)

print("\nlabel3 counts after mapping:")
print(full_df["label3"].value_counts(dropna=False))

# Save final CSV for ML pipeline
out = "/content/iot23_final.csv"
full_df.to_csv(out, index=False)
print("\nSaved cleaned file to:", out)
# Out:
# Found files:
#   /content/IoT23/Benign1/bro/conn.log.labeled
#   /content/IoT23/Benign2/bro/conn.log.labeled
#   /content/IoT23/Scan1/bro/conn.log.labeled
#   /content/IoT23/CnC1/bro/conn.log.labeled
#   /content/IoT23/CnC2/bro/conn.log.labeled
#   /content/IoT23/Scan2/bro/conn.log.labeled
# Reading /content/IoT23/Benign1/bro/conn.log.labeled
# Reading /content/IoT23/Benign2/bro/conn.log.labeled
# Reading /content/IoT23/Scan1/bro/conn.log.labeled
# Reading /content/IoT23/CnC1/bro/conn.log.labeled
# Reading /content/IoT23/CnC2/bro/conn.log.labeled
# Reading /content/IoT23/Scan2/bro/conn.log.labeled
# Concatenated shape: (38820, 23)
# Number of columns detected: 23
#
# Preview (first 6 rows):
#              ts                 uid      id_orig_h  id_orig_p  \
# 0  1.540469e+09  CGm6jB4dXK71ZDWUDh  192.168.1.132      58687
# 1  1.540469e+09  CnaDAG3n5r8eiG4su2  192.168.1.132       1900
# 2  1.540469e+09  CUrxU238nt0m6yTgKf  192.168.1.132      32893
# 3  1.540470e+09  CGQf8t1kjdxB5PHXL4  192.168.1.132      53395
# 4  1.540470e+09  CUo9DH2QDnCaBIGjkg  192.168.1.132      52801
# 5  1.540469e+09  CAvXOZ3htimWEtglii  192.168.1.132       1900
#
#          id_resp_h  id_resp_p proto service    duration orig_bytes  ...  \
# 0     216.239.35.4        123   udp       -    0.114184         48  ...
# 1  239.255.255.250       1900   udp       -  160.367579       7536  ...
# 2     216.239.35.8        123   udp       -    0.016986         48  ...
# 3       2.16.60.82        443   tcp       -    0.003497          0  ...
# 4      192.168.1.1         53   udp     dns    0.036724         34  ...
# 5  239.255.255.250       1900   udp       -  384.518261      15072  ...
#
#   local_resp missed_bytes history orig_pkts  orig_ip_bytes resp_pkts  \
# 0          -            0      Dd         1             76         1
# 1          -            0       D        24           8208         0
# 2          -            0      Dd         1             76         1
# 3          -            0   ShAFf         5            212         3
# 4          -            0      Dd         1             62         1
# 5          -            0       D        48          16416         0
#
#    resp_ip_bytes  tunnel_parents   label  label_source
# 0             76               -  benign             -
# 1              0               -  benign             -
# 2             76               -  benign             -
# 3            144               -  benign             -
# 4            339               -  benign             -
# 5              0               -  benign             -
#
# [6 rows x 23 columns]
# Column counts (non-null):
# ts                38820
# uid               38820
# id_orig_h         38820
# id_orig_p         38820
# id_resp_h         38820
# id_resp_p         38820
# proto             38820
# service           38820
# duration          38820
# orig_bytes        38820
# resp_bytes        38820
# conn_state        38820
# local_orig        38820
# local_resp        38820
# missed_bytes      38820
# history           38820
# orig_pkts         38820
# orig_ip_bytes     38820
# resp_pkts         38820
# resp_ip_bytes     38820
# tunnel_parents    38820
# label             38820
# label_source      38820
# dtype: int64
#
# Unique label values (raw):
# label
# Malicious    29486
# Benign        7508
# benign        1826
# Name: count, dtype: int64
#
# label3 counts after mapping:
# label3
# C&C       29486
# Benign     9334
# Name: count, dtype: int64
#
# Saved cleaned file to: /content/iot23_final.csv

# %%
import os, subprocess

base = "/content/IoT23"
os.makedirs(base, exist_ok=True)

scan_scenarios = [
    "CTU-IoT-Malware-Capture-7-1",
    "CTU-IoT-Malware-Capture-8-1",
    "CTU-IoT-Malware-Capture-9-1"
]

root_url = "https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios"

success = []
fail = []

for name in scan_scenarios:
    target = f"{base}/{name}/bro"
    os.makedirs(target, exist_ok=True)
    out_file = f"{target}/conn.log.labeled"
    url = f"{root_url}/{name}/bro/conn.log.labeled"
    print("Trying:", url)

    cmd = ["wget", "-q", "-O", out_file, url]
    res = subprocess.run(cmd)

    if os.path.exists(out_file) and os.path.getsize(out_file) > 0:
        print("  ✓ Downloaded", name)
        success.append(name)
    else:
        print("  ✗ Failed", name)
        fail.append(name)

print("\nSUCCESS:", success)
print("FAILED:", fail)
# Out:
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#   ✓ Downloaded CTU-IoT-Malware-Capture-7-1
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#   ✓ Downloaded CTU-IoT-Malware-Capture-8-1
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#   ✓ Downloaded CTU-IoT-Malware-Capture-9-1
#
# SUCCESS: ['CTU-IoT-Malware-Capture-7-1', 'CTU-IoT-Malware-Capture-8-1', 'CTU-IoT-Malware-Capture-9-1']
# FAILED: []

# %%
# Cell B (memory-safe streaming version)
import os
import glob
import pandas as pd
import numpy as np

base = "/content/IoT23"
paths = glob.glob(f"{base}/**/conn.log.labeled", recursive=True)
paths = sorted(paths)

print("Found", len(paths), "files:")
for p in paths:
    print(" ", p)

# Final storage list
final_chunks = []

# Standard IoT-23 conn.log columns (23 columns)
COLS = [
    "ts", "uid", "id_orig_h", "id_orig_p", "id_resp_h", "id_resp_p",
    "proto", "service", "duration", "orig_bytes", "resp_bytes",
    "conn_state", "local_orig", "local_resp", "missed_bytes",
    "history", "orig_pkts", "orig_ip_bytes", "resp_pkts",
    "resp_ip_bytes", "tunnel_parents", "label", "label_source"
]

for p in paths:
    print("\nReading:", p)

    # Load one file at a time
    df = pd.read_csv(
        p,
        sep=r"\s+",
        engine="python",
        comment="#",
        header=None
    )

    # Ensure correct number of columns
    if df.shape[1] != 23:
        print(" WARNING: File has", df.shape[1], "columns, expected 23. Fixing by trimming/padding.")
        if df.shape[1] > 23:
            df = df.iloc[:, :23]
        else:
            # pad missing cols
            for i in range(23 - df.shape[1]):
                df[f"extra{i}"] = np.nan

    df.columns = COLS

    final_chunks.append(df)
    print(" Loaded:", len(df), "rows.")

# Merge all chunks (small number of blocks)
final_df = pd.concat(final_chunks, ignore_index=True)
print("\nFINAL MERGED SHAPE:", final_df.shape)

# Clean label column
final_df["label_raw"] = final_df["label"].astype(str).str.strip()
final_df["label_raw"] = final_df["label_raw"].replace({"-": np.nan})

print("\nRaw label value counts:")
print(final_df["label_raw"].value_counts(dropna=False).head(20))

# Mapping to 3 classes
def map_label(v):
    if pd.isna(v):
        return "Unknown"
    s = str(v).lower()
    # Benign
    if "benign" in s:
        return "Benign"
    # Scan detection keywords
    if "scan" in s or "attacker" in s:
        return "Scan"
    # Many IoT-23 malicious labels use marking keywords like "botnet" or "mirai"
    if "mirai" in s or "okiru" in s or "malicious" in s or "botnet" in s:
        return "C&C"
    return "C&C"  # default malicious class

final_df["label3"] = final_df["label_raw"].apply(map_label)

print("\nlabel3 counts:")
print(final_df["label3"].value_counts(dropna=False))

# Save final dataset
out = "/content/iot23_final.csv"
final_df.to_csv(out, index=False)
print("\nSaved:", out)

# Show Scan count
scan_count = int((final_df["label3"] == "Scan").sum())
print("\nSCAN COUNT =", scan_count)
if scan_count == 0:
    print("⚠ Still no Scan labels. Additional scenarios required.")
else:
    print("🎉 Great! Scan labels detected. Ready for MNN 3-class training.")
# Out:
# Found 9 files:
#   /content/IoT23/Benign1/bro/conn.log.labeled
#   /content/IoT23/Benign2/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#   /content/IoT23/CnC1/bro/conn.log.labeled
#   /content/IoT23/CnC2/bro/conn.log.labeled
#   /content/IoT23/Scan1/bro/conn.log.labeled
#   /content/IoT23/Scan2/bro/conn.log.labeled
#
# Reading: /content/IoT23/Benign1/bro/conn.log.labeled
#  Loaded: 452 rows.
#
# Reading: /content/IoT23/Benign2/bro/conn.log.labeled
#  Loaded: 1374 rows.
#
# Reading: /content/IoT23/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled

# %%
# FINAL FIX: Chunk-based merge (RAM-safe)
import pandas as pd
import numpy as np
import glob
import os

base = "/content/IoT23"
paths = sorted(glob.glob(f"{base}/**/conn.log.labeled", recursive=True))
print("Found", len(paths), "scenario files.")

# Final output path
out_path = "/content/iot23_final.csv"

# Remove old file if exists
if os.path.exists(out_path):
    os.remove(out_path)

# Define final columns
COLS = [
    "ts", "uid", "id_orig_h", "id_orig_p", "id_resp_h", "id_resp_p",
    "proto", "service", "duration", "orig_bytes", "resp_bytes",
    "conn_state", "local_orig", "local_resp", "missed_bytes",
    "history", "orig_pkts", "orig_ip_bytes", "resp_pkts",
    "resp_ip_bytes", "tunnel_parents", "label", "label_source"
]

# Helper: convert raw label -> 3-class label
def map_label(v):
    if pd.isna(v):
        return "Unknown"
    s = str(v).lower()
    if "benign" in s:
        return "Benign"
    if "scan" in s or "attacker" in s:
        return "Scan"
    if "mirai" in s or "okiru" in s or "malicious" in s or "botnet" in s:
        return "C&C"
    return "C&C"

# Process each file in chunks of 50k
for file in paths:
    print("\nProcessing:", file)

    reader = pd.read_csv(
        file,
        sep=r"\s+",
        engine="python",
        comment="#",
        header=None,
        chunksize=50000  # CHUNK SIZE: keeps RAM under control
    )

    for chunk in reader:
        # Fix column count
        if chunk.shape[1] > 23:
            chunk = chunk.iloc[:, :23]
        elif chunk.shape[1] < 23:
            for i in range(23 - chunk.shape[1]):
                chunk[f"extra_{i}"] = np.nan

        chunk.columns = COLS

        # Clean labels
        chunk["label_raw"] = chunk["label"].astype(str).replace("-", np.nan)
        chunk["label3"] = chunk["label_raw"].apply(map_label)

        # Append chunk to output file without loading whole file
        chunk.to_csv(out_path, mode="a", index=False, header=not os.path.exists(out_path))

print("\n✔ DONE — Chunk merging finished safely.")
print("Final file saved as:", out_path)
# Out:
# Found 9 scenario files.
#
# Processing: /content/IoT23/Benign1/bro/conn.log.labeled
#
# Processing: /content/IoT23/Benign2/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CnC1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CnC2/bro/conn.log.labeled
#
# Processing: /content/IoT23/Scan1/bro/conn.log.labeled
#
# Processing: /content/IoT23/Scan2/bro/conn.log.labeled
#
# ✔ DONE — Chunk merging finished safely.
# Final file saved as: /content/iot23_final.csv

# %%
df = pd.read_csv("/content/iot23_final.csv")
print(df["label3"].value_counts())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3666105634.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("/content/iot23_final.csv")
#       2 print(df["label3"].value_counts())
#
# NameError: name 'pd' is not defined

# %%
import csv

counts = {"Benign":0, "Scan":0, "C&C":0, "Unknown":0}

with open("/content/iot23_final.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        lbl = row["label3"]
        if lbl in counts:
            counts[lbl] += 1
        else:
            counts["Unknown"] += 1

counts
# Out:
# {'Benign': 110018, 'Scan': 0, 'C&C': 17772212, 'Unknown': 0}

# %%
import os, subprocess

base = "/content/IoT23"
os.makedirs(base, exist_ok=True)

scan_scenarios = [
    "CTU-IoT-Malware-Capture-3-1",
    "CTU-IoT-Malware-Capture-4-1",
    "CTU-IoT-Malware-Capture-5-1"
]

root_url = "https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios"

success = []
fail = []

for name in scan_scenarios:
    target = f"{base}/{name}/bro"
    os.makedirs(target, exist_ok=True)
    out_file = f"{target}/conn.log.labeled"
    url = f"{root_url}/{name}/bro/conn.log.labeled"
    print("Trying:", url)

    cmd = ["wget", "-q", "-O", out_file, url]
    res = subprocess.run(cmd)

    if os.path.exists(out_file) and os.path.getsize(out_file) > 0:
        print("  ✓ Downloaded", name)
        success.append(name)
    else:
        print("  ✗ Failed", name)
        fail.append(name)

print("\nSUCCESS:", success)
print("FAILED:", fail)
# Out:
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled
#   ✓ Downloaded CTU-IoT-Malware-Capture-3-1
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-4-1/bro/conn.log.labeled
#   ✗ Failed CTU-IoT-Malware-Capture-4-1
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-5-1/bro/conn.log.labeled
#   ✗ Failed CTU-IoT-Malware-Capture-5-1
#
# SUCCESS: ['CTU-IoT-Malware-Capture-3-1']
# FAILED: ['CTU-IoT-Malware-Capture-4-1', 'CTU-IoT-Malware-Capture-5-1']

# %%
import os, subprocess

base = "/content/IoT23"
os.makedirs(base, exist_ok=True)

scan_scenarios = [
    "CTU-IoT-Malware-Capture-1-1",
    "CTU-IoT-Malware-Capture-2-1"
]

root_url = "https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios"

success = []
fail = []

for name in scan_scenarios:
    target = f"{base}/{name}/bro"
    os.makedirs(target, exist_ok=True)
    out_file = f"{target}/conn.log.labeled"
    url = f"{root_url}/{name}/bro/conn.log.labeled"
    print("Trying:", url)

    cmd = ["wget", "-q", "-O", out_file, url]
    res = subprocess.run(cmd)

    if os.path.exists(out_file) and os.path.getsize(out_file) > 0:
        print("  ✓ Downloaded", name)
        success.append(name)
    else:
        print("  ✗ Failed", name)
        fail.append(name)

print("\nSUCCESS:", success)
print("FAILED:", fail)
# Out:
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
#   ✓ Downloaded CTU-IoT-Malware-Capture-1-1
# Trying: https://mcfp.felk.cvut.cz/publicDatasets/IoT-23-Dataset/IndividualScenarios/CTU-IoT-Malware-Capture-2-1/bro/conn.log.labeled
#   ✗ Failed CTU-IoT-Malware-Capture-2-1
#
# SUCCESS: ['CTU-IoT-Malware-Capture-1-1']
# FAILED: ['CTU-IoT-Malware-Capture-2-1']

# %%
# FINAL MERGE PIPELINE - SKIPS EMPTY/INVALID FILES
import pandas as pd, numpy as np, glob, os

base = "/content/IoT23"
paths = sorted(glob.glob(f"{base}/**/conn.log.labeled", recursive=True))

print("Total files found:", len(paths))

# Filter out empty or invalid files
valid_paths = []
for p in paths:
    try:
        if os.path.getsize(p) > 1000:  # valid Zeek logs are never < 1 KB
            valid_paths.append(p)
        else:
            print("Skipping EMPTY/INVALID file:", p)
    except:
        pass

print("\nValid files for merge:", len(valid_paths))
for p in valid_paths:
    print(" ", p)

# Output file
out_path = "/content/iot23_final.csv"
if os.path.exists(out_path):
    os.remove(out_path)
print("\nRecreating:", out_path)

# Expected columns
COLS = [
    "ts","uid","id_orig_h","id_orig_p","id_resp_h","id_resp_p",
    "proto","service","duration","orig_bytes","resp_bytes",
    "conn_state","local_orig","local_resp","missed_bytes",
    "history","orig_pkts","orig_ip_bytes","resp_pkts",
    "resp_ip_bytes","tunnel_parents","label","label_source"
]

def map_label(v):
    if pd.isna(v):
        return "Unknown"
    s = str(v).lower()
    if "benign" in s:
        return "Benign"
    # broad scan indicators
    scans = ["scan","portscan","horizontal","vertical","probe","scanner","port scan"]
    if any(k in s for k in scans):
        return "Scan"
    # malicious families
    mals = ["mirai","okiru","botnet","malicious","attack","ddos"]
    if any(k in s for k in mals):
        return "C&C"
    return "C&C"

# Merge chunk-by-chunk
for file in valid_paths:
    print("\nProcessing:", file)
    try:
        reader = pd.read_csv(
            file, sep=r"\s+", engine="python",
            comment="#", header=None, chunksize=50000
        )
    except Exception as e:
        print("  Skipping due to read error:", e)
        continue

    for chunk in reader:
        if chunk.shape[1] > 23:
            chunk = chunk.iloc[:, :23]
        elif chunk.shape[1] < 23:
            for i in range(23 - chunk.shape[1]):
                chunk[f"extra_{i}"] = np.nan

        chunk.columns = COLS
        chunk["label_raw"] = chunk["label"].astype(str).replace("-", np.nan)
        chunk["label3"] = chunk["label_raw"].apply(map_label)

        # Append to final CSV safely
        chunk.to_csv(
            out_path,
            mode="a",
            index=False,
            header=(not os.path.exists(out_path) or os.path.getsize(out_path) == 0)
        )

print("\n✔ Chunk merge completed successfully.")
print("Final dataset saved at:", out_path)
# Out:
# Total files found: 14
# Skipping EMPTY/INVALID file: /content/IoT23/CTU-IoT-Malware-Capture-2-1/bro/conn.log.labeled
# Skipping EMPTY/INVALID file: /content/IoT23/CTU-IoT-Malware-Capture-4-1/bro/conn.log.labeled
# Skipping EMPTY/INVALID file: /content/IoT23/CTU-IoT-Malware-Capture-5-1/bro/conn.log.labeled
#
# Valid files for merge: 11
#   /content/IoT23/Benign1/bro/conn.log.labeled
#   /content/IoT23/Benign2/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#   /content/IoT23/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#   /content/IoT23/CnC1/bro/conn.log.labeled
#   /content/IoT23/CnC2/bro/conn.log.labeled
#   /content/IoT23/Scan1/bro/conn.log.labeled
#   /content/IoT23/Scan2/bro/conn.log.labeled
#
# Recreating: /content/iot23_final.csv
#
# Processing: /content/IoT23/Benign1/bro/conn.log.labeled
#
# Processing: /content/IoT23/Benign2/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-1-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-3-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-7-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-8-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CTU-IoT-Malware-Capture-9-1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CnC1/bro/conn.log.labeled
#
# Processing: /content/IoT23/CnC2/bro/conn.log.labeled
#
# Processing: /content/IoT23/Scan1/bro/conn.log.labeled
#
# Processing: /content/IoT23/Scan2/bro/conn.log.labeled
#
# ✔ Chunk merge completed successfully.
# Final dataset saved at: /content/iot23_final.csv

# %%
import csv

counts = {"Benign":0, "Scan":0, "C&C":0, "Unknown":0}

with open("/content/iot23_final.csv", "r") as f:
    reader = csv.DictReader(f)
    for row in reader:
        lbl = row["label3"]
        if lbl in counts:
            counts[lbl] += 1
        else:
            counts["Unknown"] += 1

print(counts)
# Out:
# {'Benign': 583829, 'Scan': 0, 'C&C': 18463252, 'Unknown': 0}

# %%
# ==========================================
# FINAL MNN IMPLEMENTATION (2-CLASS)
# Benign vs Malicious (Botnet)
# ==========================================

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
import seaborn as sns
import matplotlib.pyplot as plt

# =============================
# 1. LOAD DATA IN STREAM MODE
# =============================

print("Loading dataset in chunks (RAM-safe)...")

chunks = []
reader = pd.read_csv("/content/iot23_final.csv", chunksize=200000)  # safe chunk

for chunk in reader:
    # Keep only numeric columns + label3
    if "label3" not in chunk.columns:
        continue
    chunk = chunk.select_dtypes(include=[np.number]).assign(label3=chunk["label3"])
    chunks.append(chunk)

df = pd.concat(chunks, ignore_index=True)
print("Loaded:", df.shape)

# =============================
# 2. PREPARE LABELS (Binary)
# =============================

df = df[ df["label3"].isin(["Benign", "C&C"]) ]  # ensure only 2 classes
df["label_binary"] = df["label3"].map({"Benign":0, "C&C":1})

X = df.drop(columns=["label3","label_binary"])
y = df["label_binary"]
print("Benign:", (y==0).sum(), "Malicious:", (y==1).sum())

# ==============================================
# 3. BALANCING (Under-sample + SMOTE)
# ==============================================

print("Balancing dataset...")

# Step 1: Reduce extreme class imbalance
rus = RandomUnderSampler(sampling_strategy=0.5)
X_rus, y_rus = rus.fit_resample(X, y)

# Step 2: Apply SMOTE to boost minority class
sm = SMOTE()
X_bal, y_bal = sm.fit_resample(X_rus, y_rus)

print("Balanced shape:", X_bal.shape, "Labels:", np.bincount(y_bal))

# =============================
# 4. Train-Test Split
# =============================

X_train, X_test, y_train, y_test = train_test_split(
    X_bal, y_bal, test_size=0.25, random_state=42, stratify=y_bal)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# =============================
# 5. DEFINE MNN MODULES
# =============================

def build_module(input_dim):
    model = models.Sequential([
        layers.Dense(128, activation="relu", input_shape=(input_dim,)),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(64, activation="relu"),
        layers.BatchNormalization(),
        layers.Dropout(0.3),
        layers.Dense(1, activation="sigmoid")
    ])
    model.compile(
        optimizer=optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

input_dim = X_train.shape[1]

module_benign   = build_module(input_dim)
module_malicious = build_module(input_dim)

print("Training MNN modules...")

es = callbacks.EarlyStopping(patience=4, restore_best_weights=True)

# =============================
# 6. TRAIN MODULE 1: BENIGN
# =============================
y_benign_train = (y_train == 0).astype(int)
module_benign.fit(
    X_train, y_benign_train,
    validation_split=0.1,
    epochs=20,
    batch_size=4096,
    callbacks=[es],
    verbose=1
)

# =============================
# 7. TRAIN MODULE 2: MALICIOUS
# =============================
y_mal_train = (y_train == 1).astype(int)
module_malicious.fit(
    X_train, y_mal_train,
    validation_split=0.1,
    epochs=20,
    batch_size=4096,
    callbacks=[es],
    verbose=1
)

# =============================
# 8. FUSION (Final Prediction)
# =============================

p_ben = module_benign.predict(X_test).ravel()        # Probability of benign
p_mal = module_malicious.predict(X_test).ravel()     # Probability of malicious

# CHOOSE CLASS WITH HIGHER PROBABILITY
y_pred = np.where(p_mal > p_ben, 1, 0)

# =============================
# 9. EVALUATION
# =============================

print("\n=== FINAL MNN RESULTS ===")
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Benign", "Malicious"]))

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", xticklabels=["Benign","Malicious"], yticklabels=["Benign","Malicious"])
plt.title("Confusion Matrix")
plt.show()
# Out:
# Loading dataset in chunks (RAM-safe)...
# Loaded: (19047081, 9)
# Benign: 583829 Malicious: 18463252
# Balancing dataset...
# Balanced shape: (2335316, 8) Labels: [1167658 1167658]
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training MNN modules...
# Epoch 1/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.9035 - loss: 0.2228 - val_accuracy: 0.9779 - val_loss: 0.1470
# Epoch 2/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9825 - loss: 0.0582 - val_accuracy: 0.9813 - val_loss: 0.0976
# Epoch 3/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9862 - loss: 0.0426 - val_accuracy: 0.9869 - val_loss: 0.0503
# Epoch 4/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 12s 24ms/step - accuracy: 0.9879 - loss: 0.0350 - val_accuracy: 0.9875 - val_loss: 0.0541
# Epoch 5/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9892 - loss: 0.0289 - val_accuracy: 0.9885 - val_loss: 0.0457
# Epoch 6/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9901 - loss: 0.0256 - val_accuracy: 0.9919 - val_loss: 0.0298
# Epoch 7/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9909 - loss: 0.0226 - val_accuracy: 0.9918 - val_loss: 0.0275
# Epoch 8/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9916 - loss: 0.0210 - val_accuracy: 0.9926 - val_loss: 0.0258
# Epoch 9/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 21ms/step - accuracy: 0.9921 - loss: 0.0200 - val_accuracy: 0.9926 - val_loss: 0.0326
# Epoch 10/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 21ms/step - accuracy: 0.9926 - loss: 0.0194 - val_accuracy: 0.9935 - val_loss: 0.0217
# Epoch 11/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 24ms/step - accuracy: 0.9931 - loss: 0.0184 - val_accuracy: 0.9930 - val_loss: 0.0295
# Epoch 12/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9935 - loss: 0.0177 - val_accuracy: 0.9941 - val_loss: 0.0249
# Epoch 13/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9936 - loss: 0.0173 - val_accuracy: 0.9936 - val_loss: 0.0188
# Epoch 14/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9939 - loss: 0.0169 - val_accuracy: 0.9917 - val_loss: 0.0273
# Epoch 15/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 24ms/step - accuracy: 0.9941 - loss: 0.0163 - val_accuracy: 0.9953 - val_loss: 0.0175
# Epoch 16/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9942 - loss: 0.0161 - val_accuracy: 0.9939 - val_loss: 0.0178
# Epoch 17/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 22ms/step - accuracy: 0.9944 - loss: 0.0160 - val_accuracy: 0.9928 - val_loss: 0.0392
# Epoch 18/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9944 - loss: 0.0157 - val_accuracy: 0.9942 - val_loss: 0.0509
# Epoch 19/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9947 - loss: 0.0152 - val_accuracy: 0.9951 - val_loss: 0.0151
# Epoch 20/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 23ms/step - accuracy: 0.9946 - loss: 0.0157 - val_accuracy: 0.9954 - val_loss: 0.0149
# Epoch 1/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 25ms/step - accuracy: 0.8707 - loss: 0.3002 - val_accuracy: 0.9703 - val_loss: 0.1732
# Epoch 2/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9801 - loss: 0.0667 - val_accuracy: 0.9854 - val_loss: 0.0546
# Epoch 3/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9846 - loss: 0.0501 - val_accuracy: 0.9875 - val_loss: 0.0423
# Epoch 4/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9867 - loss: 0.0407 - val_accuracy: 0.9879 - val_loss: 0.0446
# Epoch 5/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9878 - loss: 0.0339 - val_accuracy: 0.9878 - val_loss: 0.0325
# Epoch 6/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 22ms/step - accuracy: 0.9890 - loss: 0.0291 - val_accuracy: 0.9902 - val_loss: 0.0378
# Epoch 7/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9904 - loss: 0.0244 - val_accuracy: 0.9913 - val_loss: 0.0289
# Epoch 8/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9910 - loss: 0.0224 - val_accuracy: 0.9922 - val_loss: 0.0210
# Epoch 9/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - accuracy: 0.9916 - loss: 0.0208 - val_accuracy: 0.9929 - val_loss: 0.0243
# Epoch 10/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 11s 27ms/step - accuracy: 0.9919 - loss: 0.0203 - val_accuracy: 0.9930 - val_loss: 0.0192
# Epoch 11/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 19s 23ms/step - accuracy: 0.9923 - loss: 0.0195 - val_accuracy: 0.9941 - val_loss: 0.0232
# Epoch 12/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.9929 - loss: 0.0184 - val_accuracy: 0.9926 - val_loss: 0.0177
# Epoch 13/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9934 - loss: 0.0175 - val_accuracy: 0.9941 - val_loss: 0.0177
# Epoch 14/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 24ms/step - accuracy: 0.9934 - loss: 0.0176 - val_accuracy: 0.9940 - val_loss: 0.0168
# Epoch 15/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9939 - loss: 0.0165 - val_accuracy: 0.9944 - val_loss: 0.0180
# Epoch 16/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9941 - loss: 0.0163 - val_accuracy: 0.9944 - val_loss: 0.0235
# Epoch 17/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 10s 25ms/step - accuracy: 0.9940 - loss: 0.0162 - val_accuracy: 0.9944 - val_loss: 0.0188
# Epoch 18/20
# 385/385 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - accuracy: 0.9944 - loss: 0.0158 - val_accuracy: 0.9949 - val_loss: 0.0202
# 18245/18245 ━━━━━━━━━━━━━━━━━━━━ 18s 974us/step
# 18245/18245 ━━━━━━━━━━━━━━━━━━━━ 17s 941us/step
#
# === FINAL MNN RESULTS ===
# Accuracy: 0.9950208023239682
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Benign       1.00      0.99      1.00    291915
#    Malicious       0.99      1.00      1.00    291914
#
#     accuracy                           1.00    583829
#    macro avg       1.00      1.00      1.00    583829
# weighted avg       1.00      1.00      1.00    583829
